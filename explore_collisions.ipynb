# %%
import pandas as pd

collisions_df = pd.read_csv("dft-road-casualty-statistics-collision-2025.csv")
casualties_df = pd.read_csv("dft-road-casualty-statistics-casualty-2025.csv")

# %%
collisions_df
# Out:
#        collision_index  collision_year collision_ref_no  \
# 0        202517H102225            2025        17H102225
# 1        2025070815222            2025        070815222
# 2        2025070937984            2025        070937984
# 3        2025041687395            2025        041687395
# 4        2025161555094            2025        161555094
# ...                ...             ...              ...
# 101520   2025622500238            2025        622500238
# 101521   2025622500335            2025        622500335
# 101522   2025610038025            2025        610038025
# 101523   2025610009425            2025        610009425
# 101524   2025631632945            2025        631632945
#
#         location_easting_osgr  location_northing_osgr  longitude  latitude  \
# 0                    449216.0                534979.0   -1.23770  54.70743
# 1                    363808.0                389192.0   -2.54576  53.39831
# ...

# %%
casualties_df
# Out:
#        collision_index  collision_year collision_ref_no  vehicle_reference  \
# 0        2025010555120            2025        010555120                  1
# 1        2025010555533            2025        010555533                  3
# 2        2025010555864            2025        010555864                  1
# 3        2025010558295            2025        010558295                  1
# 4        2025010558923            2025        010558923                  1
# ...                ...             ...              ...                ...
# 127878   2025351612912            2025        351612912                  2
# 127879   2025991585031            2025        991585031                  1
# 127880   2025101663507            2025        101663507                  1
# 127881   2025161636644            2025        161636644                  2
# 127882   2025461600385            2025        461600385                  1
#
# ...

# %%
collisions_df['collision_index'].nunique() == len(collisions_df)
# Out:
# True

# %%
mismatched = casualties_df[~casualties_df['collision_index'].isin(collisions_df['collision_index'])]
print(len(mismatched))
# Out:
# 0

# %%
no_casualties = collisions_df[~collisions_df['collision_index'].isin(casualties_df['collision_index'])]
print(len(no_casualties))
# Out:
# 0

# %%
casualties_df['casualty_severity'].unique()
# Out:
# array([3, 2, 1])
